# %% [markdown]
# <a href="https://colab.research.google.com/github/shrushtipatil778-afk/Hangman_game/blob/main/Copy_of_hangman_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

words = ["python", "computer", "programming", "developer", "coding"]

word = random.choice(words)
guessed_letters = []
wrong_guesses = 0
max_wrong_guesses = 6

print("🎮 Welcome to Hangman Game!")
print("Guess the word one letter at a time.")

while wrong_guesses < max_wrong_guesses:
    display_word = ""

    for letter in word:
        if letter in guessed_letters:
            display_word += letter + " "
        else:
            display_word += "_ "

    print("\nWord:", display_word)
    print("Wrong guesses:", wrong_guesses, "/", max_wrong_guesses)

    if all(letter in guessed_letters for letter in word):
        print("🎉 Congratulations! You won!")
        break

    guess = input("Enter a letter: ").lower()

    if len(guess) != 1 or not guess.isalpha():
        print("Please enter one valid letter.")
        continue

    if guess in guessed_letters:
        print("You already guessed this letter.")
        continue

    guessed_letters.append(guess)

    if guess in word:
        print("✅ Correct guess!")
    else:
        wrong_guesses += 1
        print("❌ Wrong guess!")

else:
    print("\n😢 Game Over!")
    print("The word was:", word)
# Out:
# 🎮 Welcome to Hangman Game!
# Guess the word one letter at a time.
#
# Word: _ _ _ _ _ _
# Wrong guesses: 0 / 6
# Enter a letter: o
# ✅ Correct guess!
#
# Word: _ o _ _ _ _
# Wrong guesses: 0 / 6
# Enter a letter: c
# ✅ Correct guess!
#
# Word: c o _ _ _ _
# Wrong guesses: 0 / 6
# Enter a letter: d
# ✅ Correct guess!
#
# Word: c o d _ _ _
# Wrong guesses: 0 / 6
# Enter a letter: i
# ✅ Correct guess!
#
# Word: c o d i _ _
# Wrong guesses: 0 / 6
# Enter a letter: n
# ✅ Correct guess!
#
# Word: c o d i n _
# Wrong guesses: 0 / 6
# Enter a letter: g
# ✅ Correct guess!
#
# Word: c o d i n g
# Wrong guesses: 0 / 6
# 🎉 Congratulations! You won!
