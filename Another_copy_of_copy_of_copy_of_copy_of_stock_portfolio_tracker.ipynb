# %% [markdown]
# <a href="https://colab.research.google.com/github/shrushtipatil778-afk/Hangman_game/blob/main/Another_copy_of_copy_of_copy_of_copy_of_stock_portfolio_tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
0
# Stock Portfolio Tracker

stock_prices = {
    "AAPL": 180,
    "TSLA": 250,
    "GOOGL": 150,
    "AMZN": 200,
    "MSFT": 300
}

total_investment = 0

print("📊 Stock Portfolio Tracker")
print("Available stocks:", ", ".join(stock_prices.keys()))

while True:
    stock = input("\nEnter stock name (or 'DONE' to finish): ").strip().upper()

    if stock == "DONE":
        break

    if stock not in stock_prices:
        print("❌ Stock not available!")
        continue

    quantity = int(input("Enter quantity: "))

    investment = stock_prices[stock] * quantity
    total_investment += investment

    print("✅ Investment in", stock, "=", investment)

print("\n💰 Total Investment =", total_investment)
# Out:
# 📊 Stock Portfolio Tracker
# Available stocks: AAPL, TSLA, GOOGL, AMZN, MSFT
#
# Enter stock name (or 'DONE' to finish): AAPL
# Enter quantity: 2
# ✅ Investment in AAPL = 360
#
# Enter stock name (or 'DONE' to finish): TSLA
# Enter quantity: 3
# ✅ Investment in TSLA = 750
#
# Enter stock name (or 'DONE' to finish): 3
# ❌ Stock not available!
#
# Enter stock name (or 'DONE' to finish): DONE
#
# 💰 Total Investment = 1110
